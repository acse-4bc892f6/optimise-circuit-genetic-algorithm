# %% [markdown]
# ## The report of task 5

# %% [markdown]
# ### MAX_EVOLUTIONS

# %% [markdown]
# In this part, In order to get the speed of convergence clearly, a judgment condition has been added to test: exit the iteration when convergence reaches the maximum value. As we have already known that the optimal fitness value is 375.496 by making multiple tests. Therefore, we add the condition that "the_max_value < 375.496" into the while loop to make sure we can record the run time, k and other relative parameters correctly.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For the accuracy of the data, each data will be run at last 10 times for calculating the average. Here, we research the parameter "MAX_EVOLUTIONS" firstly.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We change the value of the MAX_EVOLUTIONS from 300 to 5000, at each value, we test the best fitness value and its runtime for ten times and take the average. Then we run the program for 100 times and record the times of the final max_fitness_value has not reached the optimal fitness value,375.496. At last, we use the matlab to draw the diagram.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The result is:

# %% [markdown]
# ![differenttimes.jpg](attachment:differenttimes.jpg)

# %% [markdown]
# Time will certainly increase with the number of iterations, but performance is not always the best. We can see that when the MAX_EVOLUTIONS is smaller than 2000, the runtime gradually increase until reach the level around 14s. In the this period, the success rate of the program reaches the optimal fitness increases from only 1% to 91%. After the MAX_EVOLUTIONS is equal and bigger than 2000, the change of each parameter is not obvious. By the way, in the test, we exit the iteration when convergence reaches the maximum value immediately. However, if we have not tested the code for a lot of times and know the what the what the optimal fitness value is, the bigger MAX_EVOLUTIONS generally means the bigger runtime. For us, we should firstly make sure high success rate of reaching the idea value, therefore, we do not consider the MAX_EVOLUTIONS which is smaller than 2000. Then we need to consider the runtime of our program, so we find the that the situation where the MAX_EVOLUTIONS is equal to 2000 is the best choice, as it has a 99% success rate and a low runtime.

# %% [markdown]
# ### Child

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then we change the parameter of the number of child. We increase it from 50 to 1000 generally under the condition that crossover pro equals to 0.95 and MAX_EVOLUTIONS equals to 3000. At each value, we test the k and its runtime for ten times and take the average. At last, use the matlab to draw the diagram.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The result is:

# %% [markdown]
# ![child_0.95.jpg](attachment:child_0.95.jpg)

# %% [markdown]
# We can see that in the figure, both the runtime and k has the same trend. When the number of child increases from 0 to 100, both k and runtime decreases. In the period of the number of child is between 100 and 200, both k and runtime are in the lowest point in the diagram. After that, until the number of child reach 500, the k and runtime stops the increase trend and start to stably decrease. Obviously, when chid number is 100 to 200. It is the fastest, because the program doesn't spend too much time creating child, and also don't need too many iterations because the sample is too small.

# %% [markdown]
# ### Crossover

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We change the parameter of the crossover. We increase it from 0.8 to 1 generally under the condition that number of child equals to 100 and MAX_EVOLUTIONS equals to 3000. At each value, we test the k and its runtime for ten times and take the average. At last, use the matlab to draw the diagram.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The result is:

# %% [markdown]
# ![cossover_posibility_100.jpg](attachment:cossover_posibility_100.jpg)

# %% [markdown]
# For cross over possibility，0.9 and 0.8 took the least time, but 0.85 and 1 were slow.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Although for cross over possibility，0.9 and 0.8 took the least time and 0.85 and 1 were slow. However, in the reliability experiment, the performance of 0.85 is the best.

# %% [markdown]
# ### Child - Fitness value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![ft_child_0.95_1000.jpg](attachment:ft_child_0.95_1000.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![ft_0.95_1500.jpg](attachment:ft_0.95_1500.jpg)

# %% [markdown]
# Obviously, time increases with the number of children , but performance does not rise significantly as the number of children increases, and even decreases, because it is stuck in a local optimum. As can be seen from the chart, the performance of 200 children is best and at a not bad time
